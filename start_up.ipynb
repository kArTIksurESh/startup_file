# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/arib168/data/main/50_Startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
labels=df['State'].value_counts()
labels
# Out:
# New York      17
# California    17
# Florida       16
# Name: State, dtype: int64

# %%
plt.plot(labels)

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
#R&D spend
sns.regplot(x=df['R&D Spend'],y=y,color='red')

# %%
#Administration  
sns.regplot(x=df['Administration'],y=y)

# %%
#Marketing Spend
sns.regplot(x=df['Marketing Spend'],y=y,color='green')

# %%
#state
sns.regplot(x=df['State'],y=y,color='yellow')
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-13-2fb42356553b> in <module>
#       1 #state
# ----> 2 sns.regplot(x=df['State'],y=y,color='yellow')
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861     scatter_kws["marker"] = marker
#     862     line_kws = {} if line_kws is None else copy.copy(line_kws)
# ...

# %%
#encoding_method(one_hot)

from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
col_transfer=make_column_transformer((OneHotEncoder(handle_unknown='ignore'),['State']),remainder='passthrough')
x=col_transfer.fit_transform(x)
x
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.6534920e+05,
#         1.3689780e+05, 4.7178410e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.6259770e+05,
#         1.5137759e+05, 4.4389853e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.5344151e+05,
#         1.0114555e+05, 4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.4437241e+05,
#         1.1867185e+05, 3.8319962e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.4210734e+05,
#         9.1391770e+04, 3.6616842e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.3187690e+05,
#         9.9814710e+04, 3.6286136e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.3461546e+05,
#         1.4719887e+05, 1.2771682e+05],
#        [0.0000000e+00, 1.0000000e+00, 0.0000000e+00, 1.3029813e+05,
#         1.4553006e+05, 3.2387668e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 1.2054252e+05,
#         1.4871895e+05, 3.1161329e+05],
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.30)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(xtrain,ytrain)
y_pred=reg.predict(xtest)
y_pred
# Out:
# array([147902.15015996,  98345.65898572,  57263.7714303 , 127757.19421037,
#         91046.71288349, 195352.62599089, 165235.65951557, 151686.13451341,
#         74271.62380531, 111173.7752357 ,  82572.16383176, 136641.06202382,
#         45563.00208302,  74969.39057455,  98691.01430709])

# %%
df1=pd.DataFrame({'actual value':ytest,'predicted value':y_pred,'difference':ytest-y_pred})
df1
# Out:
#     actual value  predicted value    difference
# 15     129917.04    147902.150160 -17985.110160
# 32      97427.84     98345.658986   -917.818986
# 46      49490.75     57263.771430  -7773.021430
# 13     134307.35    127757.194210   6550.155790
# 35      96479.51     91046.712883   5432.797117
# 0      192261.83    195352.625991  -3090.795991
# 5      156991.12    165235.659516  -8244.539516
# 14     132602.65    151686.134513 -19083.484513
# 40      78239.91     74271.623805   3968.286195
# 23     108733.99    111173.775236  -2439.785236
# 39      81005.76     82572.163832  -1566.403832
# 10     146121.95    136641.062024   9480.887976
# 47      42559.73     45563.002083  -3003.272083
# 41      77798.83     74969.390575   2829.439425
# 33      96778.92     98691.014307  -1912.094307

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,r2_score

print("MAE :",mean_absolute_error(ytest,y_pred))
print("MAPE :",mean_absolute_percentage_error(ytest,y_pred))
print("MAE :",mean_squared_error(ytest,y_pred))
print("r2_score :",r2_score(ytest,y_pred))
# Out:
# MAE : 6285.192837059674
# MAPE : 0.060438193754704224
# MAE : 68904885.33008656
# r2_score : 0.9557058863753551
